# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/joelporcaro/Metis/project2/coffee_regression/df.csv')
df.head()
# Out:
#    Unnamed: 0  Country  Year        Income        Age  Schooling  \
# 0           0  Austria  2001  20180.945132  67.876884        9.2
# 1           1  Austria  2001  20180.945132  67.876884        9.2
# 2           2  Austria  2002  21814.009616  67.900458        9.4
# 3           3  Austria  2002  21814.009616  67.900458        9.4
# 4           4  Austria  2003  26659.666724  67.873489        9.6
#
#    Unemployment   Hours Continent  Price
# 0          4.01  1535.0    Europe   2.93
# 1          4.01  1669.0    Europe   2.93
# 2          4.85  1530.0    Europe   2.86
# 3          4.85  1666.0    Europe   2.86
# 4          4.78  1524.0    Europe   3.18

# %%
df = df.drop(['Unnamed: 0'], axis =1)

# %%
df.head()
# Out:
#    Country  Year        Income        Age  Schooling  Unemployment   Hours  \
# 0  Austria  2001  20180.945132  67.876884        9.2          4.01  1535.0
# 1  Austria  2001  20180.945132  67.876884        9.2          4.01  1669.0
# 2  Austria  2002  21814.009616  67.900458        9.4          4.85  1530.0
# 3  Austria  2002  21814.009616  67.900458        9.4          4.85  1666.0
# 4  Austria  2003  26659.666724  67.873489        9.6          4.78  1524.0
#
#   Continent  Price
# 0    Europe   2.93
# 1    Europe   2.93
# 2    Europe   2.86
# 3    Europe   2.86
# 4    Europe   3.18

# %%
len(df.Country.unique())
# Out:
# 20

# %%
sns.pairplot(df)

# %%
plt.scatter(df.Price, df.Income)

# %%
len(df.Country.unique())
# Out:
# 20

# %%
df.Year.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017])
